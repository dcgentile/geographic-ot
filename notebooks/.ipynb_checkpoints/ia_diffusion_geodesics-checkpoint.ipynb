# %%
import total
import os
import numpy as np
import pandas as pd 
import seaborn as sns
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import geopandas
from libpysal import weights
from gerrychain import Graph

img_dir = os.path.join(".", "geodesic_stills")

# %%
filename = "./IA_counties/IA_counties.shp"
voter_df = pd.read_csv("./data/voter_data.csv")
ia_graph = Graph.from_file(filename)
ia_counties = geopandas.read_file(filename)
ia_adj=nx.adjacency_matrix(ia_graph).toarray()
centroids = np.column_stack((ia_counties.centroid.x, ia_counties.centroid.y))
queen = weights.Queen.from_dataframe(ia_counties)
graph = queen.to_networkx()
positions = dict(zip(graph.nodes, centroids))
num_nodes = len(graph.nodes)
# Out:
# /usr/local/lib/python3.11/site-packages/gerrychain/graph/graph.py:179: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   areas = df.geometry.area.to_dict()
# /var/folders/4x/f1jfbfg16zx42jnp08s19sc00000gn/T/ipykernel_40207/2031526601.py:6: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = np.column_stack((ia_counties.centroid.x, ia_counties.centroid.y))
# /var/folders/4x/f1jfbfg16zx42jnp08s19sc00000gn/T/ipykernel_40207/2031526601.py:7: FutureWarning: `use_index` defaults to False but will default to True in future. Set True/False directly to control this behavior and silence this warning
#   queen = weights.Queen.from_dataframe(ia_counties)

# %%
ia_counties.head()
ia_counties[['NAME10']]
# Out:
#            NAME10
# 0        Marshall
# 1          Benton
# 2            Clay
# 3          Shelby
# 4         Clayton
# ..            ...
# 94            Lee
# 95          Story
# 96         Grundy
# 97  Pottawattamie
# 98         Howard
#
# [99 rows x 1 columns]

# %%
def compute_graph_resistance(graph):
    ia_laplace = nx.laplacian_matrix(ia_graph).toarray()
    mpinv = np.linalg.pinv(ia_laplace)
    num_nodes = len(graph.nodes)
    metric = np.zeros((num_nodes, num_nodes))
    for i in range(num_nodes):
        for j in range(num_nodes):
            delta = np.zeros(num_nodes)
            delta[i] = 1
            delta[j] = -1
            metric[i,j] = (delta.T @ mpinv @ delta) 
    return metric

def compute_graph_metric(graph):
    graph_dists = dict(nx.shortest_path_length(graph))
    sorted_dists = {k:sorted(v.items()) for k, v in graph_dists.items()}
    num_nodes = len(graph.nodes)
    dist_mat = np.zeros((num_nodes, num_nodes))
    for i in range(num_nodes):
        for j in range(num_nodes):
            dist_mat[i,j] = sorted_dists[i][j][1]
    
    return dist_mat

def iter_experiment(its_lo, its_hi, its_step, measures, cost, epsilon, steps):
    for its in range(its_lo, its_hi, its_step):
        tot_geodesic = total.build_geodesic(measures, cost, epsilon, loss="sqeuc", method="total", steps=steps, iters=its)
        pot_geodesic = total.build_geodesic(measures, cost, epsilon, method="", steps=steps)
        #tot_ratio = np.divide(tot_geodesic, pot_geodesic, out=np.zeros_like(pot_geodesic))
        tot_ratio = tot_geodesic/pot_geodesic
        tot_rel_err = abs(np.ones((num_nodes, steps)) - tot_ratio)
        fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
        fig.set_size_inches(16,8)
        sns.heatmap(tot_geodesic, ax=ax1)
        sns.heatmap(pot_geodesic, ax=ax2)
        sns.heatmap(tot_rel_err, ax = ax3)
        return fig, tot_rel_err

# %%
def comparison_video(measures, cost, epsilon, steps, its, filename, metric, p=2):
    w1_geodesic = total.build_geodesic(measures, cost, epsilon, method="total", steps=steps, iters=its)
    w2_geodesic = total.build_geodesic(measures, cost ** p, epsilon, method="total", steps=steps, iters=its)
    pot_w1_geodesic = total.build_geodesic(measures, cost, epsilon, method="", steps=steps, iters=its)
    pot_w2_geodesic = total.build_geodesic(measures, cost ** p, epsilon, method="", steps=steps, iters=its)
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
    fig.set_size_inches(20,20)
     
    dir_name = "p-comparison-anims/"
    still_dir = os.path.join(img_dir, dir_name)
    if not os.path.isdir(still_dir):
        os.mkdir(still_dir)
     
    def update(frame):
        size = 500
        nx.draw(graph, positions, ax=ax1, node_size=size, node_color=w2_geodesic[:, frame])
        nx.draw(graph, positions, ax=ax2, node_size=size, node_color=w1_geodesic[:, frame])
        nx.draw(graph, positions, ax=ax3, node_size=size, node_color=pot_w2_geodesic[:, frame])
        nx.draw(graph, positions, ax=ax4, node_size=size, node_color=pot_w1_geodesic[:, frame])
        ax1.set_title(
            f"W{p}: {metric}\n Timestep : {frame + 1}"
            )
        ax2.set_title(
            f"W1: {metric}\n Timestep : {frame + 1}"
            )
        ax3.set_title(
            f"POT W{p}: {metric}\n Timestep : {frame + 1}"
            )
        ax4.set_title(
            f"POT W1: {metric}\n Timestep : {frame + 1}"
            )
    ani = animation.FuncAnimation(fig=fig, func=update, frames=steps, interval=100)
    ani.save(os.path.join(dir_name, filename), writer='ffmpeg')

def draw_endpoints(measures, cost, epsilon, steps, its, filename, metric):
    w1_geodesic = total.build_geodesic(measures, cost, epsilon, method="total", steps=steps, iters=its)
    w2_geodesic = total.build_geodesic(measures, cost ** 2, epsilon, method="total", steps=steps, iters=its)
    pot_w1_geodesic = total.build_geodesic(measures, cost, epsilon, method="", steps=steps, iters=its)
    pot_w2_geodesic = total.build_geodesic(measures, cost ** 2, epsilon, method="", steps=steps, iters=its)
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
    fig.set_size_inches(20,20)
     
    dir_name = "p-comparison-stills/"
    still_dir = os.path.join(img_dir, dir_name)
    if not os.path.isdir(still_dir):
        os.mkdir(still_dir)
    
    lo, hi = 0, steps - 1
    size=500
    nx.draw(graph, positions, ax=ax1, node_size=size, node_color=w2_geodesic[:, lo])
    nx.draw(graph, positions, ax=ax2, node_size=size, node_color=w1_geodesic[:, hi])
    nx.draw(graph, positions, ax=ax3, node_size=size, node_color=w2_geodesic[:, lo])
    nx.draw(graph, positions, ax=ax4, node_size=size, node_color=w1_geodesic[:, hi])
    ax1.set_title(
        f"W2: {metric}\n Timestep : {lo + 1}"
        )
    ax2.set_title(
        f"W1: {metric}\n Timestep : {hi + 1}"
        )
    ax3.set_title(
        f"W2: {metric}\n Timestep : {lo + 1}"
        )
    ax4.set_title(
        f"W1: {metric}\n Timestep : {hi + 1}"
        )
    plt.savefig(os.path.join(dir_name, filename))

# %%
graph_metric_cost = compute_graph_metric(graph)
ia_markov = total.adj_mat_to_markov_chain(ia_adj)
diff_cost = total.form_diffusion_map(ia_markov, 3)
squared_diff_cost = diff_cost ** 2

# %%
t = 1000
graph_metric_cost = compute_graph_metric(graph)
ia_markov = total.adj_mat_to_markov_chain(ia_adj)
diff_cost = total.form_diffusion_map(ia_markov, t)
squared_diff_cost = diff_cost ** 2
fig, (ax0, ax1, ax2) = plt.subplots(1,3)
fig.set_size_inches(18, 5)
size=300
n = 74
nx.draw(graph, positions, ax=ax0, node_size=size, node_color=graph_metric_cost[n])
nx.draw(graph, positions, ax=ax1, node_size=size, node_color=diff_cost[n])
nx.draw(graph, positions, ax=ax2, node_size=size, node_color=squared_diff_cost[n])

# %%
def animate_diff_dist(graph, steps=250, n=74, size=300, filename="ia_diffusion_evolution.mp4"):
    fig, (ax0, ax1) = plt.subplots(1,2)
    fig.set_size_inches(16, 8)
    ia_markov = total.adj_mat_to_markov_chain(ia_adj)
    def update(frame):
        if frame % (int(steps/10)) == 0:
            print(frame)
        diff_cost = total.form_diffusion_map(ia_markov, frame * 10)
        squared_diff_cost = diff_cost ** 2
        nx.draw(graph, positions, ax=ax0, node_size=size, node_color=diff_cost[n])
        nx.draw(graph, positions, ax=ax1, node_size=size, node_color=squared_diff_cost[n])
    ani = animation.FuncAnimation(fig=fig, func=update, frames=steps, interval=100)
    ani.save(filename, writer='ffmpeg')

animate_diff_dist(graph)
# Out:
# 0
# 0
# 25
# 50
# 75
# 100
# 125
# 150
# 175
# 200
# 225

# %%
ia_markov = total.adj_mat_to_markov_chain(ia_adj)
c0, c1 = 78, 43
mu_0 = total.random_geographic_concentration(cost, center=c0)
mu_1 = total.random_geographic_concentration(cost, center=c1)
its = 256
for t in range(20):
    diff_cost = total.form_diffusion_map(ia_markov, t)
    filename = f"diffusion-{t}-endpoints.pdf"
    draw_endpoints(measures, diff_cost, epsilon, steps, its, filename, f"Diffusion Time {t}")

# %%
c0, c1 = 78, 43
mu_0 = total.random_geographic_concentration(cost, center=c0)
mu_1 = total.random_geographic_concentration(cost, center=c1)
its = 256
for i in range(5):
    for t in [5, 10, 15, 20]:
        diff_cost = total.form_diffusion_map(ia_markov, t)
        p = 1 - (1 / (i + 1))
        filename = f"ia-diff-metric-{t}-time-{p}-power.mp4"
        comparison_video(measures, diff_cost, epsilon, steps, its, filename, f"Diffusion Metric, t = {t}", p=p)

# %%
ia_markov = total.adj_mat_to_markov_chain(ia_adj)
t = 10
diff_cost = total.form_diffusion_map(ia_markov, t)
graph_cost = graph_metric_cost
resist_cost = resistance_metric_cost
its = 256
for _ in range(1):
    #c0, c1 = np.random.randint(num_nodes), np.random.randint(num_nodes)
    c0, c1 = 78, 43
    mu_0 = total.random_geographic_concentration(cost, center=c0)
    mu_1 = total.random_geographic_concentration(cost, center=c1)
    measures = np.stack((mu_0, mu_1)).T
    epsilon = 0.1
    steps = 50
    #filename = f"ia-graph-metric-geodesic-{c0}-to-{c1}.mp4"
    #comparison_video(measures, graph_cost, epsilon, steps, its, filename, "Graph Metric")
    #filename = f"ia-diffusion-metric-geodesic-{c0}-to-{c1}.mp4"
    #comparison_video(measures, diff_cost, epsilon, steps, its, filename, r"Diffusion Distance w/ $t = 10$")
    filename = f"ia-resistance-metric-geodesic-{c0}-to-{c1}.mp4"
    comparison_video(measures, resist_cost, epsilon, steps, its, filename, r"Resistance Distance w/ $t = 10$")
# Out:
# computing with TOTAL implementation
# computing with TOTAL implementation
# computing using Python OT library
# computing using Python OT library

# %%
cost = graph_metric_cost
c0, c1 = np.random.randint(num_nodes), np.random.randint(num_nodes)
for power in range(6, 12):
    its = 2 ** power
    filename = f"ia-squared-graph-metric-geodesic-{c0}-to-{c1}-its-{its}.mp4"
    comparison_video(measures, cost, epsilon, steps, its, filename, "Natural Graph Distance")

# %%
c0, c1 = np.random.randint(num_nodes), np.random.randint(num_nodes)
t = 10
ia_markov = total.adj_mat_to_markov_chain(ia_adj)
cost = total.form_diffusion_map(ia_markov, t) ** 2
for power in range(6, 12):
    its = 2 ** power
    filename = f"ia-diffusion-metric-geodesic-{c0}-to-{c1}-its-{its}.mp4"
    comparison_video(measures, cost, epsilon, steps, its, filename, f"Diffusion Distance, t = {t}")
# Out:
# computing with TOTAL implementation
# computing using Python OT library
# computing with TOTAL implementation
# computing using Python OT library
# computing with TOTAL implementation
# computing using Python OT library
# computing with TOTAL implementation
# computing using Python OT library
# computing with TOTAL implementation
# computing using Python OT library
# computing with TOTAL implementation
# computing using Python OT library

# %%
its = 2048
cost = graph_metric_cost ** 2
fig, rel_err= iter_experiment(its, its + 1, its, measures, cost, epsilon, steps) 
plt.show()
# Out:
# computing with TOTAL implementation
# computing using Python OT library

# %%
fig,ax=plt.subplots()
ia_counties.plot(linewidth=1, ax=ax, edgecolor="grey", facecolor="white")
nx.draw(graph, positions, ax=ax, with_labels=True, node_color=cost[c0])
plt.savefig(f"distance-from-node-{c0}.pdf")

# %%
t = 10
ia_adj = nx.adjacency_matrix(ia_graph)
ia_markov = total.adj_mat_to_markov_chain(ia_adj)
cost = total.form_diffusion_map(ia_markov, t) ** 2
tot_geodesic= total.build_geodesic(measures, cost, epsilon, method="total", steps=steps)
pot_geodesic= total.build_geodesic(measures, cost, epsilon, method="", steps=steps)
rel_err = abs(np.ones((num_nodes, steps)) - tot_geodesic/ pot_geodesic)
fig, (ax1, ax2, ax3) = plt.subplots(1,3)
fig.set_size_inches(16, 8)
sns.heatmap(tot_geodesic, ax=ax1)
sns.heatmap(pot_geodesic, ax=ax2)
sns.heatmap(rel_err, ax=ax3)
ax1.set_title("Our Implementation")
ax2.set_title("POT Implementation")
ax3.set_title("Pointwise Relative Error")
plt.savefig("diff-dist-geodesic-comparison.pdf")

# %%
errors = [np.mean(abs(1 - tot_geodesic[:, step] / pot_geodesic[:, step])) for step in range(0, steps)]
sns.lineplot(errors)

# %%
cost = graph_metric_cost ** 2
filename = f"ia-squared-graph-metric-geodesic-{c0}-to-{c1}.mp4"
tot_geodesic = total.build_geodesic(measures, cost, epsilon, method="total", steps=steps, iters=its)
pot_geodesic = total.build_geodesic(measures, cost, epsilon, method="", steps=steps)
fig, (ax1, ax2) = plt.subplots(1, 2)
 
dir_name = "graph-dist/"
still_dir = os.path.join(img_dir, dir_name)
if not os.path.isdir(still_dir):
    os.mkdir(still_dir)
 
def update(frame):
    nx.draw(graph, positions, ax=ax1, node_size=50, node_color=tot_geodesic[:, frame])
    nx.draw(graph, positions, ax=ax2, node_size=50, node_color=pot_geodesic[:, frame])
    ax1.set_title(
        f"TOTAL: Natural Graph Distance\n Timestep : {frame + 1}"
    )
    ax2.set_title(
        f"POT: Natural Graph Distance\n Timestep : {frame + 1}"
    )

ani = animation.FuncAnimation(fig=fig, func=update, frames=steps, interval=100)
ani.save(filename, writer='ffmpeg')
# Out:
# computing with TOTAL implementation
# computing using Python OT library

# %%
ia_markov = total.adj_mat_to_markov_chain(ia_adj)

def update(frame):
    nx.draw(graph, positions, ax=ax, node_size=50, node_color=geodesic[:, frame])
    ax.set_title(
        f"Walking Along a Wasserstein Geodesic Under the Diffusion Distacne\n Timestep : {frame + 1}"
    )
    return ax

for t in range(0, 10, 1):
    ia_diffusion = total.form_diffusion_map(ia_markov, t) ** 2
    steps = 50
    geodesic = total.build_geodesic(measures, ia_diffusion, epsilon, method="", steps=steps)
    fig, ax = plt.subplots()
    ia_counties.plot(linewidth=1, ax=ax, edgecolor="grey", facecolor="white")
    steps = np.arange(50)
    dir_name = f"squared-diffusion-time-{t}-pot/"
    still_dir = os.path.join(img_dir, dir_name)
    if not os.path.isdir(still_dir):
        os.mkdir(still_dir)
    
    for step in steps:
        nx.draw(graph, positions, ax=ax, node_size=50, node_color=geodesic[:, step])
        still_filename = f"ia_diffusion_t_{t}_geodesic_{step}.pdf"
        still_path = os.path.join(still_dir, still_filename)
        plt.savefig(still_path, bbox_inches='tight')
#
    filename = os.path.join(img_dir, f"ia_squared_diffusion-time-{t}-pot.mp4")
    ani = animation.FuncAnimation(fig=fig, func=update, frames=steps, interval=100)
    ani.save(filename, writer='ffmpeg')

# %%
fig,ax = plt.subplots()
for t in range(1,11):
    ia_diffusion = total.form_diffusion_map(ia_markov, t)
    ia_counties.plot(linewidth=1, ax=ax, edgecolor="grey", facecolor="white")
    nx.draw(graph, positions, ax=ax, node_size=50, node_color=ia_diffusion[34])
    ax.set_title(f"Diffusion Distance from Node 34 at Time {t}")
    plt.savefig(f"diffusion-dist-from-34-time-{t}.pdf")
